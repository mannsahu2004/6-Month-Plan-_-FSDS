# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open(r'D:\NIT\img.jpg')
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=474x328>

# %%
type(img)
# Out:
# PIL.WebPImagePlugin.WebPImageFile
